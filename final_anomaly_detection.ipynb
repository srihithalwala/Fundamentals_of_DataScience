# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from keras.models import Model
from keras.layers import Input, Dense
# Out:
# 2023-07-29 14:48:01.492850: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-29 14:48:01.644351: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-29 14:48:01.645973: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-29 14:48:03.150250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Step 1: Import the dataset
data = pd.read_csv("healthcare_providers.csv")

# %%
data.head()
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# 3                            NaN                          MD
# 4                              E                          DO
#
#   Gender of the Provider Entity Type of the Provider  \
# 0                      F                           I
# 1                      F                           I
# 2                      M                           I
# 3                      M                           I
# 4                      M                           I
#
#   Street Address 1 of the Provider Street Address 2 of the Provider  ...  \
# 0                1402 S GRAND BLVD                   FDT 14TH FLOOR  ...
# 1                  2950 VILLAGE DR                              NaN  ...
# 2                20 WASHINGTON AVE                          STE 212  ...
# 3               5746 N BROADWAY ST                              NaN  ...
# 4                 875 MILITARY TRL                        SUITE 200  ...
#
#   HCPCS Code                                  HCPCS Description  \
# 0      99223  Initial hospital inpatient care, typically 70 ...
# 1      G0202  Screening mammography, bilateral (2-view study...
# 2      99348  Established patient home visit, typically 25 m...
# 3      81002                            Urinalysis, manual test
# 4      96372  Injection beneath the skin or into muscle for ...
#
#   HCPCS Drug Indicator Number of Services Number of Medicare Beneficiaries  \
# 0                    N                 27                               24
# 1                    N                175                              175
# 2                    N                 32                               13
# 3                    N                 20                               18
# 4                    N                 33                               24
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                 27
# 1                                                175
# 2                                                 32
# 3                                                 20
# 4                                                 31
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                    200.58777778                    305.21111111
# 1                          123.73                           548.8
# 2                           90.65                             155
# 3                             3.5                               5
# 4                           26.52                              40
#
#   Average Medicare Payment Amount Average Medicare Standardized Amount
# 0                    157.26222222                         160.90888889
# 1                          118.83                         135.31525714
# 2                      64.4396875                           60.5959375
# 3                            3.43                                 3.43
# 4                    19.539393939                         19.057575758
#
# [5 rows x 27 columns]

# %%
# Step 2: Handle missing values (if any)
# Check for missing values in each column
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  index                                                           0
# National Provider Identifier                                    0
# Last Name/Organization Name of the Provider                     0
# First Name of the Provider                                   4255
# Middle Initial of the Provider                              29331
# Credentials of the Provider                                  7209
# Gender of the Provider                                       4254
# Entity Type of the Provider                                     0
# Street Address 1 of the Provider                                0
# Street Address 2 of the Provider                            59363
# City of the Provider                                            0
# Zip Code of the Provider                                        0
# State Code of the Provider                                      0
# Country Code of the Provider                                    0
# Provider Type                                                   0
# Medicare Participation Indicator                                0
# Place of Service                                                0
# HCPCS Code                                                      0
# HCPCS Description                                               0
# HCPCS Drug Indicator                                            0
# Number of Services                                              0
# Number of Medicare Beneficiaries                                0
# Number of Distinct Medicare Beneficiary/Per Day Services        0
# Average Medicare Allowed Amount                                 0
# Average Submitted Charge Amount                                 0
# Average Medicare Payment Amount                                 0
# Average Medicare Standardized Amount                            0
# dtype: int64

# %%
data.dtypes
# Out:
# index                                                         int64
# National Provider Identifier                                  int64
# Last Name/Organization Name of the Provider                  object
# First Name of the Provider                                   object
# Middle Initial of the Provider                               object
# Credentials of the Provider                                  object
# Gender of the Provider                                       object
# Entity Type of the Provider                                  object
# Street Address 1 of the Provider                             object
# Street Address 2 of the Provider                             object
# City of the Provider                                         object
# Zip Code of the Provider                                    float64
# State Code of the Provider                                   object
# Country Code of the Provider                                 object
# Provider Type                                                object
# Medicare Participation Indicator                             object
# Place of Service                                             object
# HCPCS Code                                                   object
# HCPCS Description                                            object
# HCPCS Drug Indicator                                         object
# Number of Services                                           object
# Number of Medicare Beneficiaries                             object
# Number of Distinct Medicare Beneficiary/Per Day Services     object
# Average Medicare Allowed Amount                              object
# Average Submitted Charge Amount                              object
# Average Medicare Payment Amount                              object
# Average Medicare Standardized Amount                         object
# dtype: object

# %%
data[['First Name of the Provider','Middle Initial of the Provider', 'Credentials of the Provider', 'Gender of the Provider', 'Street Address 2 of the Provider']] = data[['First Name of the Provider','Middle Initial of the Provider', 'Credentials of the Provider', 'Gender of the Provider', 'Street Address 2 of the Provider']].fillna('')

# %%
data
# Out:
#          index  National Provider Identifier  \
# 0      8774979                    1891106191
# 1      3354385                    1346202256
# 2      3001884                    1306820956
# 3      7594822                    1770523540
# 4       746159                    1073627758
# ...        ...                           ...
# 99995  3837311                    1386938868
# 99996  2079360                    1215091327
# 99997  8927965                    1902868185
# 99998  8854571                    1891941183
# 99999  3547535                    1356772156
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                     UPADHYAYULA                  SATYASREE
# 1                                           JONES                      WENDY
# 2                                        DUROCHER                    RICHARD
# 3                                         FULLARD                     JASPER
# 4                                        PERROTTI                    ANTHONY
# ...                                           ...                        ...
# 99995                                       PAPES                       JOAN
# 99996                                      HAYNER                   MARGARET
# 99997                                    VALENCIA                       DANA
# 99998                              GONZALEZ-LAMOS                    RAFAELA
# 99999                                    RAMEZANI                     ELIIAN
#
#       Middle Initial of the Provider Credentials of the Provider  \
# 0                                                           M.D.
# 1                                  P                        M.D.
# 2                                  W                         DPM
# 3                                                             MD
# 4                                  E                          DO
# ...                              ...                         ...
# 99995                                                         PT
# 99996                              S                        ARNP
# 99997                                                       M.D.
# 99998
# 99999
#
#       Gender of the Provider Entity Type of the Provider  \
# 0                          F                           I
# 1                          F                           I
# 2                          M                           I
# 3                          M                           I
# 4                          M                           I
# ...                      ...                         ...
# 99995                      F                           I
# 99996                      F                           I
# 99997                      M                           I
# 99998                      F                           I
# 99999                      F                           I
#
#       Street Address 1 of the Provider Street Address 2 of the Provider  ...  \
# 0                    1402 S GRAND BLVD                   FDT 14TH FLOOR  ...
# 1                      2950 VILLAGE DR                                   ...
# 2                    20 WASHINGTON AVE                          STE 212  ...
# 3                   5746 N BROADWAY ST                                   ...
# 4                     875 MILITARY TRL                        SUITE 200  ...
# ...                                ...                              ...  ...
# 99995               324 E BALTIMORE ST                                   ...
# 99996                    645 NW 4TH ST                                   ...
# 99997                 3009 N BALLAS RD                       SUITE 202B  ...
# 99998              2365 BOSTON POST RD                        SUITE 201  ...
# 99999        444 MIDDLE NECK RD APT 1H                                   ...
#
#       HCPCS Code                                  HCPCS Description  \
# 0          99223  Initial hospital inpatient care, typically 70 ...
# 1          G0202  Screening mammography, bilateral (2-view study...
# 2          99348  Established patient home visit, typically 25 m...
# 3          81002                            Urinalysis, manual test
# 4          96372  Injection beneath the skin or into muscle for ...
# ...          ...                                                ...
# 99995      97162  Evaluation of physical therapy, typically 30 m...
# 99996      99213  Established patient office or other outpatient...
# 99997      93320  Doppler ultrasound study of heart blood flow, ...
# 99998      G0008          Administration of influenza virus vaccine
# 99999      97112  Therapeutic procedure to re-educate brain-to-n...
#
#       HCPCS Drug Indicator Number of Services  \
# 0                        N                 27
# 1                        N                175
# 2                        N                 32
# 3                        N                 20
# 4                        N                 33
# ...                    ...                ...
# 99995                    N                 20
# 99996                    N                136
# 99997                    N                 11
# 99998                    N                 12
# 99999                    N                589
#
#       Number of Medicare Beneficiaries  \
# 0                                   24
# 1                                  175
# 2                                   13
# 3                                   18
# 4                                   24
# ...                                ...
# 99995                               20
# 99996                              107
# 99997                               11
# 99998                               12
# 99999                               76
#
#       Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                     27
# 1                                                    175
# 2                                                     32
# 3                                                     20
# 4                                                     31
# ...                                                  ...
# 99995                                                 20
# 99996                                                136
# 99997                                                 11
# 99998                                                 12
# 99999                                                587
#
#       Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                        200.58777778                    305.21111111
# 1                              123.73                           548.8
# 2                               90.65                             155
# 3                                 3.5                               5
# 4                               26.52                              40
# ...                               ...                             ...
# 99995                         85.3725                             214
# 99996                           61.27                    144.05147059
# 99997                           17.98                    109.54545455
# 99998                           30.54                              65
# 99999                    38.601052632                    46.867572156
#
#       Average Medicare Payment Amount Average Medicare Standardized Amount
# 0                        157.26222222                         160.90888889
# 1                              118.83                         135.31525714
# 2                          64.4396875                           60.5959375
# 3                                3.43                                 3.43
# 4                        19.539393939                         19.057575758
# ...                               ...                                  ...
# 99995                         60.7255                              62.2485
# 99996                    30.006176471                         37.040220588
# 99997                           14.09                                14.62
# 99998                           29.93                                25.32
# 99999                    29.736876061                         25.912139219
#
# [100000 rows x 27 columns]

# %%
# Step 3: Select features for anomaly detection
# Let's consider 'Number of Services' and 'Average Medicare Payment Amount' as relevant features for anomaly detection.
features = ['Number of Services', 'Average Medicare Payment Amount']
X = data[features]
data['Number of Services'] = data['Number of Services'].str.replace(',', '').astype(float)
data['Average Medicare Payment Amount'] = data['Average Medicare Payment Amount'].str.replace(',', '').astype(float)

# %%
# Step 4: Impute missing values for numerical features
# Assuming 'Number of Services' and 'Average Medicare Payment Amount' are numerical features, we'll fill NaN values with the mean.
data['Number of Services'].fillna(data['Number of Services'].mean(), inplace=True)
data['Average Medicare Payment Amount'].fillna(data['Average Medicare Payment Amount'].mean(), inplace=True)

# %%
# Step 5: Convert categorical variables (if any)
data = pd.get_dummies(data, columns=['Gender of the Provider', 'Entity Type of the Provider'], drop_first=True)

# %%
data
# Out:
#          index  National Provider Identifier  \
# 0      8774979                    1891106191
# 1      3354385                    1346202256
# 2      3001884                    1306820956
# 3      7594822                    1770523540
# 4       746159                    1073627758
# ...        ...                           ...
# 99995  3837311                    1386938868
# 99996  2079360                    1215091327
# 99997  8927965                    1902868185
# 99998  8854571                    1891941183
# 99999  3547535                    1356772156
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                     UPADHYAYULA                  SATYASREE
# 1                                           JONES                      WENDY
# 2                                        DUROCHER                    RICHARD
# 3                                         FULLARD                     JASPER
# 4                                        PERROTTI                    ANTHONY
# ...                                           ...                        ...
# 99995                                       PAPES                       JOAN
# 99996                                      HAYNER                   MARGARET
# 99997                                    VALENCIA                       DANA
# 99998                              GONZALEZ-LAMOS                    RAFAELA
# 99999                                    RAMEZANI                     ELIIAN
#
#       Middle Initial of the Provider Credentials of the Provider  \
# 0                                                           M.D.
# 1                                  P                        M.D.
# 2                                  W                         DPM
# 3                                                             MD
# 4                                  E                          DO
# ...                              ...                         ...
# 99995                                                         PT
# 99996                              S                        ARNP
# 99997                                                       M.D.
# 99998
# 99999
#
#       Street Address 1 of the Provider Street Address 2 of the Provider  \
# 0                    1402 S GRAND BLVD                   FDT 14TH FLOOR
# 1                      2950 VILLAGE DR
# 2                    20 WASHINGTON AVE                          STE 212
# 3                   5746 N BROADWAY ST
# 4                     875 MILITARY TRL                        SUITE 200
# ...                                ...                              ...
# 99995               324 E BALTIMORE ST
# 99996                    645 NW 4TH ST
# 99997                 3009 N BALLAS RD                       SUITE 202B
# 99998              2365 BOSTON POST RD                        SUITE 201
# 99999        444 MIDDLE NECK RD APT 1H
#
#       City of the Provider  Zip Code of the Provider  ... Number of Services  \
# 0              SAINT LOUIS               631041004.0  ...               27.0
# 1             FAYETTEVILLE               283043815.0  ...              175.0
# 2              NORTH HAVEN                64732343.0  ...               32.0
# 3              KANSAS CITY               641183998.0  ...               20.0
# 4                  JUPITER               334585700.0  ...               33.0
# ...                    ...                       ...  ...                ...
# 99995           WILMINGTON               604811236.0  ...               20.0
# 99996              REDMOND               977561502.0  ...              136.0
# 99997          SAINT LOUIS               631312322.0  ...               11.0
# 99998            LARCHMONT               105383500.0  ...               12.0
# 99999           GREAT NECK                   11023.0  ...              589.0
#
#       Number of Medicare Beneficiaries  \
# 0                                   24
# 1                                  175
# 2                                   13
# 3                                   18
# 4                                   24
# ...                                ...
# 99995                               20
# 99996                              107
# 99997                               11
# 99998                               12
# 99999                               76
#
#       Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                     27
# 1                                                    175
# 2                                                     32
# 3                                                     20
# 4                                                     31
# ...                                                  ...
# 99995                                                 20
# 99996                                                136
# 99997                                                 11
# 99998                                                 12
# 99999                                                587
#
#       Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                        200.58777778                    305.21111111
# 1                              123.73                           548.8
# 2                               90.65                             155
# 3                                 3.5                               5
# 4                               26.52                              40
# ...                               ...                             ...
# 99995                         85.3725                             214
# 99996                           61.27                    144.05147059
# 99997                           17.98                    109.54545455
# 99998                           30.54                              65
# 99999                    38.601052632                    46.867572156
#
#       Average Medicare Payment Amount Average Medicare Standardized Amount  \
# 0                          157.262222                         160.90888889
# 1                          118.830000                         135.31525714
# 2                           64.439688                           60.5959375
# 3                            3.430000                                 3.43
# 4                           19.539394                         19.057575758
# ...                               ...                                  ...
# 99995                       60.725500                              62.2485
# 99996                       30.006176                         37.040220588
# 99997                       14.090000                                14.62
# 99998                       29.930000                                25.32
# 99999                       29.736876                         25.912139219
#
#       Gender of the Provider_F  Gender of the Provider_M  \
# 0                         True                     False
# 1                         True                     False
# 2                        False                      True
# 3                        False                      True
# 4                        False                      True
# ...                        ...                       ...
# 99995                     True                     False
# 99996                     True                     False
# 99997                    False                      True
# 99998                     True                     False
# 99999                     True                     False
#
#       Entity Type of the Provider_O
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ...                             ...
# 99995                         False
# 99996                         False
# 99997                         False
# 99998                         False
# 99999                         False
#
# [100000 rows x 28 columns]

# %%
# Step 6: Select features for anomaly detection
features = ['Number of Services', 'Average Medicare Payment Amount']
X = data[features]

# %%
# Step 6: Select features for anomaly detection
features = ['Number of Services', 'Average Medicare Payment Amount']
X = data[features]

# Step 7: Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Print the first few rows of the preprocessed data
print("Preprocessed Data:\n", pd.DataFrame(X_scaled, columns=features).head())
# Out:
# Preprocessed Data:
#     Number of Services  Average Medicare Payment Amount
# 0           -0.085301                         0.400082
# 1           -0.025939                         0.207649
# 2           -0.083296                        -0.064687
# 3           -0.088109                        -0.370166
# 4           -0.082895                        -0.289505

# %%
#: Apply unsupervised anomaly detection algorithms
# Isolation Forest
isolation_forest = IsolationForest(contamination=0.05, random_state=42)
outliers_if = isolation_forest.fit_predict(X_scaled)
scores_if = -isolation_forest.decision_function(X_scaled)

# %%
# X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)
# svm = OneClassSVM(nu=0.05)
# outliers_svm = svm.fit_predict(X_train)
# scores_svm = svm.decision_function(X_test)

# %%
#One-Class SVM
svm = OneClassSVM(nu=0.05)
outliers_svm = svm.fit_predict(X_scaled)
scores_svm = svm.decision_function(X_scaled)

# %%
# Local Outlier Factor (LOF)
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)
outliers_lof = lof.fit_predict(X_scaled)
scores_lof = -lof.negative_outlier_factor_

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_if, cmap='viridis', label='Isolation Forest')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('Isolation Forest Anomaly Detection')
plt.colorbar()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_svm, cmap='coolwarm', marker='x', label='One-Class SVM')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('One-Class SVM Anomaly Detection')
plt.colorbar()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 3)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_lof, cmap='plasma', label='Local Outlier Factor')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('Local Outlier Factor Anomaly Detection')
plt.colorbar()
plt.tight_layout()
plt.show()

# %%
#Apply Autoencoders for anomaly detection
# Split the data into training and testing sets
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# %%
# Build the Autoencoder model
input_layer = Input(shape=(X_train.shape[1],))
encoded = Dense(10, activation='relu')(input_layer)  # Smaller hidden layer
decoded = Dense(X_train.shape[1], activation='linear')(encoded)  # Output layer

# %%
autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the Autoencoder on normal data (without outliers)
autoencoder.fit(X_train, X_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

# %%
# Use the trained Autoencoder to predict the reconstruction error on test data
predictions = autoencoder.predict(X_test)
reconstruction_error = np.mean(np.square(predictions - X_test), axis=1)
# Out:
# 625/625 [==============================] - 2s 3ms/step

# %%
# Define a threshold for anomaly detection based on the reconstruction error
threshold = np.percentile(reconstruction_error, 95)  # For example, using the 95th percentile as the threshold

# %%
# Identify anomalies based on the threshold
outliers_autoencoder = (reconstruction_error > threshold).astype(int)

# %%
# Step 7: Visualize the results

# Scatter plot of the original data with outliers marked by color
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_if, cmap='viridis', label='Isolation Forest')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('Isolation Forest Anomaly Detection')
plt.colorbar()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_svm, cmap='coolwarm', marker='x', label='One-Class SVM')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('One-Class SVM Anomaly Detection')
plt.colorbar()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 3)
plt.scatter(X['Number of Services'], X['Average Medicare Payment Amount'], c=outliers_lof, cmap='plasma', label='Local Outlier Factor')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('Local Outlier Factor Anomaly Detection')
plt.colorbar()

# %%
plt.figure(figsize=(12, 8))
num_points_to_plot = 5000
plt.subplot(2, 2, 4)
plt.scatter(X['Number of Services'][:num_points_to_plot], X['Average Medicare Payment Amount'][:num_points_to_plot], c=outliers_autoencoder[:num_points_to_plot], cmap='cool', marker='s', label='Autoencoder')
plt.xlabel('Number of Services')
plt.ylabel('Average Medicare Payment Amount')
plt.title('Autoencoder Anomaly Detection')
plt.colorbar()

plt.tight_layout()
plt.show()

# %%
# Histogram of decision scores for each algorithm
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.hist(scores_if, bins=50, color='purple', alpha=0.7)
plt.xlabel('Isolation Forest Decision Score')
plt.ylabel('Frequency')
plt.title('Isolation Forest Decision Scores')
# Out:
# Text(0.5, 1.0, 'Isolation Forest Decision Scores')

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 2)
plt.hist(scores_svm, bins=50, color='orange', alpha=0.7)
plt.xlabel('One-Class SVM Decision Score')
plt.ylabel('Frequency')
plt.title('One-Class SVM Decision Scores')
# Out:
# Text(0.5, 1.0, 'One-Class SVM Decision Scores')

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 3)
plt.hist(scores_lof, bins=50, color='green', alpha=0.7)
plt.xlabel('Local Outlier Factor Decision Score')
plt.ylabel('Frequency')
plt.title('Local Outlier Factor Decision Score')
# Out:
# Text(0.5, 1.0, 'Local Outlier Factor Decision Score')
